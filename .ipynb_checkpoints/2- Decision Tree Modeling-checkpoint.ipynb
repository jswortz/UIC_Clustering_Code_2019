# %% [markdown]
# # Now that the basic statistics are understood, the plan is to cluster employees into "look-a-likes" and then find business rules for attrition using decision trees

# %%
# !conda install -y python-graphviz #install packages needed
# !pip install sklearn

# %%
import pandas as pd
import seaborn as sns
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
data = pd.read_csv("https://raw.githubusercontent.com/jswortz/UIC_Clustering_Code_2019/master/data/WA_Fn-UseC_-HR-Employee-Attrition.csv")


print("Data Shape: {} rows x {} cols".format(len(data), len(data.columns)))
data.head()
# Out:
# Data Shape: 1470 rows x 35 cols
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %% [markdown]
# # Fix Data Elements

# %%
dropCols = ["EmployeeCount", "MonthlyIncome", "Over18", "StandardHours"]

data = data.drop(dropCols, axis=1) #axis = 1 indicates column space

#create binary target 0/1 left variable

data['target'] = data['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)

data = data.drop('Attrition', axis = 1)

num_cols = data._get_numeric_data().columns

num_cols = list(set(num_cols) - set(['target']))

# %% [markdown]
# # Begin Modeling Code

# %% [markdown]
# # Next steps - analyze the data for varying attrition rates and descriptions of the clusters using decision trees to find business rules

# %%
from sklearn import tree
import graphviz
from ipywidgets import interact


def graphRules( max_depth=3, min_samples_split=20, min_samples_leaf=2,
              max_features=10):

    # Separating out the features
    X = data.loc[:, num_cols].values #todo - add categorical variables later

    # Separating out the target
    y = data.loc[:,['target']].values


    clf = tree.DecisionTreeClassifier(max_depth=max_depth, min_samples_split=min_samples_split,
                                      min_samples_leaf=min_samples_leaf,max_features=max_features,
                                      random_state=109
                                     )
    clf = clf.fit(X, y)

    dot_data = tree.export_graphviz(clf, out_file=None, 
                         feature_names=num_cols,  
                         class_names=['stay', 'attrite'],  
                         filled=True, rounded=True,  
                         special_characters=True)  
    graph = graphviz.Source(dot_data)  
    return(graph)
    
g = interact(graphRules, max_depth=(1,20,1), min_samples_split=(2,100,4), min_samples_leaf=(2,100,10),
              max_features=(1,23,1))
# Out:
# interactive(children=(IntSlider(value=3, description='max_depth', max=20, min=1), IntSlider(value=20, descript…

# %% [markdown]
# # What other opportunities are there?
# # What would a full Machine Learning solution look like?
# # What are the models to consider?
